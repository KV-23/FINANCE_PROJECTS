# %% [markdown]
# <a href="https://colab.research.google.com/github/KV-23/FINANCE_PROJECTS/blob/main/Decision_Tree_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#in this we use decisiontree to predict stock prices

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import pandas as pd

# %%
# !pip install yfinance
import yfinance as yf

# %%
import datetime
from datetime import time

# %%
end_date=datetime.date.today()
print(end_date)
df=yf.download('AMZN',start='2013-01-01',end=end_date.strftime('%Y-%m-%d'))
df
# Out:
# 2024-08-13
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-01-02   12.804000   12.905000   12.663000   12.865500   12.865500
# 2013-01-03   12.863500   13.044000   12.818500   12.924000   12.924000
# 2013-01-04   12.879000   12.990000   12.832500   12.957500   12.957500
# 2013-01-07   13.148500   13.486500   13.133500   13.423000   13.423000
# 2013-01-08   13.353500   13.449000   13.178500   13.319000   13.319000
# ...                ...         ...         ...         ...         ...
# 2024-08-06  161.710007  165.080002  158.539993  161.929993  161.929993
# 2024-08-07  166.550003  167.580002  161.429993  162.770004  162.770004
# 2024-08-08  165.169998  166.690002  162.550003  165.800003  165.800003
# 2024-08-09  166.399994  168.550003  165.850006  166.940002  166.940002
# 2024-08-12  168.139999  168.550003  166.110001  166.800003  166.800003
#
#               Volume
# ...

# %%
df['Price_up']=np.where(df['Adj Close'].shift(-1)<df['Adj Close'],1,0)
df[['Adj Close','Price_up']]
# Out:
#              Adj Close  Price_up
# Date
# 2013-01-02   12.865500         0
# 2013-01-03   12.924000         0
# 2013-01-04   12.957500         0
# 2013-01-07   13.423000         1
# 2013-01-08   13.319000         1
# ...                ...       ...
# 2024-08-06  161.929993         0
# 2024-08-07  162.770004         0
# 2024-08-08  165.800003         0
# 2024-08-09  166.940002         1
# 2024-08-12  166.800003         0
#
# [2922 rows x 2 columns]

# %%
X=df.iloc[:,0:df.shape[1]-1].values#Getting all columns except last
Y=df.iloc[:,-1].values#Getting only last column

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
tree=DecisionTreeClassifier().fit(X_train,Y_train)
print(tree.score(X_test,Y_test))
# Out:
# 0.5367521367521367
